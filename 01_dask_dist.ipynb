# %%
import os
import cdsw
from src.cml_extensions.dask_cluster.dask_cluster import DaskCluster

#os.environ[""]

cluster = DaskCluster(num_workers=10, worker_cpu=16, worker_memory=360, scheduler_cpu=160, scheduler_memory=360)
cluster.init()
# Out:
# --------------------
# Dask cluster started
# --------------------
#
# The Dask dashboard is running at
# https://jonksrerbstwfoec.ml-f0942348-224.paul-aug.a465-9q4k.cloudera.site/status
#
# To connect to this Dask cluster from this CML Session,
# use the following Python code:
#   from dask.distributed import Client
#   client = Client('tcp://100.100.149.204:8786')

# %%
from multiprocessing import cpu_count
import time

# %%
cpu_count()
# Out:
# 192

# %%
from dask.distributed import Client
client = Client('tcp://100.100.149.204:8786')

client
# Out:
# <Client: 'tcp://100.100.149.204:8786' processes=10 threads=1920, memory=3.27 TiB>

# %% [markdown]
# ## Read Parquet from S3

# %%
import os
import dask.dataframe as dd

df = dd.read_parquet("s3://paul-aug26-buk-a3c2b50a/data/pdefusco/modin/10kcols_100parts")
df.head()
# Out:
#   col1       col2       col3       col4       col5       col6       col7  \
# 0    A  2155749.0  2162552.0  8879422.0  3592760.0  6260197.0  4380193.0
# 1    B  1461406.0  6489945.0  1028377.0   252657.0  7100934.0  1732775.0
# 2    C  1327473.0  8855601.0  9027891.0  6230956.0  3983144.0  1449433.0
# 3    D  4750508.0  7597960.0  6513623.0  2545998.0   252819.0  8349154.0
# 4    E  7268317.0  6482051.0  8168993.0  7054196.0  3747121.0  6873729.0
#
#         col8       col9      col10  ...    col9990    col9991    col9992  \
# 0   649749.0  8567364.0  7842953.0  ...  8791386.0  7131687.0  3073450.0
# 1  9956641.0  3115993.0  4463726.0  ...  4568265.0  2932271.0  7233633.0
# 2  3296800.0  4257279.0  8776295.0  ...  4033020.0  9059617.0  4739562.0
# 3  8894517.0  6153052.0  2255401.0  ...  2636969.0  3686812.0  2764838.0
# 4  2527835.0  1162200.0  2718198.0  ...  9561350.0  6701099.0  6449186.0
#
#      col9993    col9994    col9995    col9996    col9997    col9998    col9999
# 0  6205936.0  8928314.0  6583948.0   796539.0   704542.0  5869669.0  2844541.0
# 1  4212719.0  8254713.0  9958355.0  4085747.0  2868795.0  7255552.0  4432626.0
# 2  1724006.0  3691998.0  7474958.0  2359813.0  1789445.0  4224895.0  4994013.0
# 3   570953.0  7414366.0  1492267.0  3544097.0  9573390.0  4342891.0  2768177.0
# 4  9719908.0  6537810.0  9959078.0  5823777.0  3433689.0  6322195.0  7372708.0
#
# [5 rows x 9999 columns]

# %%
df._meta
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11, col12, col13, col14, col15, col16, col17, col18, col19, col20, col21, col22, col23, col24, col25, col26, col27, col28, col29, col30, col31, col32, col33, col34, col35, col36, col37, col38, col39, col40, col41, col42, col43, col44, col45, col46, col47, col48, col49, col50, col51, col52, col53, col54, col55, col56, col57, col58, col59, col60, col61, col62, col63, col64, col65, col66, col67, col68, col69, col70, col71, col72, col73, col74, col75, col76, col77, col78, col79, col80, col81, col82, col83, col84, col85, col86, col87, col88, col89, col90, col91, col92, col93, col94, col95, col96, col97, col98, col99, col100, ...]
# Index: []
#
# [0 rows x 9999 columns]

# %%
df.npartitions
# Out:
# 100

# %%
#df.optimize().pprint()

# %% [markdown]
# ### Dataframe Operations

# %%
start_time = time.time()
df.groupby("col1").mean().compute()
print(f"time taken: {time.time() - start_time}")
# Out:
# time taken: 93.59771847724915

# %%
start_time = time.time()
df.groupby("col1").sum().compute()
print(f"time taken: {time.time() - start_time}")
# Out:
# time taken: 55.398688316345215

# %% [markdown]
# ### Concat

# %%
df2 = dd.read_parquet("s3://paul-aug26-buk-a3c2b50a/data/pdefusco/modin/10kcols_100parts")

# %%
df3 = dd.concat([df,df2],axis=0)

# %%
start_time = time.time()
df3.groupby("col1").mean().compute()
print(f"time taken: {time.time() - start_time}")
# Out:
# time taken: 208.32689690589905

# %%
df4 = dd.read_parquet("s3://paul-aug26-buk-a3c2b50a/data/pdefusco/modin/10kcols_100parts")

# %%
df5 = dd.read_parquet("s3://paul-aug26-buk-a3c2b50a/data/pdefusco/modin/10kcols_100parts")

# %%
df6 = dd.read_parquet("s3://paul-aug26-buk-a3c2b50a/data/pdefusco/modin/10kcols_100parts")

# %%
df7 = dd.read_parquet("s3://paul-aug26-buk-a3c2b50a/data/pdefusco/modin/10kcols_100parts")

# %%
df8 = dd.read_parquet("s3://paul-aug26-buk-a3c2b50a/data/pdefusco/modin/10kcols_100parts")

# %%
df9 = dd.concat([df,df2,df4,df5,df6,df7,df8],axis=0)

# %%
start_time = time.time()
df9.groupby("col1").sum().compute()
print(f"time taken: {time.time() - start_time}")
# Out:
# time taken: 546.5301249027252

# %%
df9.head()
# Out:
#   col1       col2       col3       col4       col5       col6       col7  \
# 0    A  2155749.0  2162552.0  8879422.0  3592760.0  6260197.0  4380193.0
# 1    B  1461406.0  6489945.0  1028377.0   252657.0  7100934.0  1732775.0
# 2    C  1327473.0  8855601.0  9027891.0  6230956.0  3983144.0  1449433.0
# 3    D  4750508.0  7597960.0  6513623.0  2545998.0   252819.0  8349154.0
# 4    E  7268317.0  6482051.0  8168993.0  7054196.0  3747121.0  6873729.0
#
#         col8       col9      col10  ...    col9990    col9991    col9992  \
# 0   649749.0  8567364.0  7842953.0  ...  8791386.0  7131687.0  3073450.0
# 1  9956641.0  3115993.0  4463726.0  ...  4568265.0  2932271.0  7233633.0
# 2  3296800.0  4257279.0  8776295.0  ...  4033020.0  9059617.0  4739562.0
# 3  8894517.0  6153052.0  2255401.0  ...  2636969.0  3686812.0  2764838.0
# 4  2527835.0  1162200.0  2718198.0  ...  9561350.0  6701099.0  6449186.0
#
#      col9993    col9994    col9995    col9996    col9997    col9998    col9999
# 0  6205936.0  8928314.0  6583948.0   796539.0   704542.0  5869669.0  2844541.0
# 1  4212719.0  8254713.0  9958355.0  4085747.0  2868795.0  7255552.0  4432626.0
# 2  1724006.0  3691998.0  7474958.0  2359813.0  1789445.0  4224895.0  4994013.0
# 3   570953.0  7414366.0  1492267.0  3544097.0  9573390.0  4342891.0  2768177.0
# 4  9719908.0  6537810.0  9959078.0  5823777.0  3433689.0  6322195.0  7372708.0
#
# [5 rows x 9999 columns]

# %%
df2 = df2.drop("col1", axis=1)
df4 = df4.drop("col1", axis=1)
df5 = df5.drop("col1", axis=1)
df6 = df6.drop("col1", axis=1)
df7 = df7.drop("col1", axis=1)
df8 = df8.drop("col1", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df2 = df2.drop("col1", axis=1)
#       2 df4 = df4.drop("col1", axis=1)
#       3 df5 = df5.drop("col1", axis=1)
#
# File ~/.local/lib/python3.10/site-packages/dask_expr/_collection.py:3293, in DataFrame.drop(self, labels, axis, columns, errors)
#    3289 elif axis == 0 and columns is None:
#    3290     raise NotImplementedError(
#    3291         "Drop currently only works for axis=1 or when columns is not None"
#    3292     )
# -> 3293 return new_collection(expr.Drop(self, columns=columns, errors=errors))
#
# File ~/.local/lib/python3.10/site-packages/dask_expr/_collection.py:4799, in new_collection(expr)
#    4797 def new_collection(expr):
#    4798     """Create new collection from an expr"""
# -> 4799     meta = expr._meta
#    4800     expr._name  # Ensure backend is imported
#    4801     return get_collection_type(meta)(expr)
#
# File /usr/local/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/.local/lib/python3.10/site-packages/dask_expr/_expr.py:496, in Blockwise._meta(self)
#     493 @functools.cached_property
#     494 def _meta(self):
#     495     args = [op._meta if isinstance(op, Expr) else op for op in self._args]
# --> 496     return self.operation(*args, **self._kwargs)
#
# File ~/.local/lib/python3.10/site-packages/dask/dataframe/utils.py:772, in drop_by_shallow_copy(df, columns, errors)
#     770 if not pd.api.types.is_list_like(columns):
#     771     columns = [columns]
# --> 772 df2.drop(columns=columns, inplace=True, errors=errors)
#     773 return df2
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['col1'] not found in axis"

# %%
df_list=[df,df2,df4,df5,df6,df7,df8]
for i, df in enumerate(df_list, 1):
    df.columns = [col_name+'_df{}'.format(i) for col_name in df.columns]

# %%
df10 = dd.concat(df_list,axis=1)

# %%
start_time = time.time()
df10.groupby("col1_df1").sum().compute()
print(f"time taken: {time.time() - start_time}")
# Out:
# time taken: 356.1294870376587

# %% [markdown]
# ### Repartitioning Data

# %%
df.memory_usage(deep=True)
# Out:
# Dask Series Structure:
# npartitions=1
#     int64
#       ...
# Dask Name: memoryusageframe, 2 expressions
# Expr=ReadParquetFSSpec(fb0ee25).memoryusageframe(deep=True)

# %%
df.memory_usage_per_partition(index=True, deep=False)
# Out:
# Dask Series Structure:
# npartitions=5000
#     int64
#       ...
#     ...
#       ...
#       ...
# Dask Name: operation, 2 expressions
# Expr=MemoryUsagePerPartition(frame=ReadParquetFSSpec(fb0ee25))

# %%
type(a)
# Out:
# dask_expr._collection.Series

# %%
a.compute()
# Out:
# /home/cdsw/.local/lib/python3.10/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 25.60 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# 0    399828
# 0    399828
# 0    399828
# 0    399828
# 0    399828
#       ...
# 0    399828
# 0    399828
# 0    399828
# 0    399828
# 0    399828
# Length: 5000, dtype: int64

# %%
df = df.repartition(npartitions=1)
df.memory_usage_per_partition(index=True, deep=False).compute()
# Out:
# /home/cdsw/.local/lib/python3.10/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 25.29 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# 0    2002500000
# dtype: int64

# %%
df = df.repartition(partition_size="100MB")
df.memory_usage_per_partition(index=True, deep=False).compute()
# Out:
# /home/cdsw/.local/lib/python3.10/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 25.28 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /home/cdsw/.local/lib/python3.10/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 25.32 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# 0    95355045
# 0    95359050
# 0    95355045
# 0    95359050
# 0    95355045
# 0    95359050
# 0    95355045
# 0    95359050
# 0    95355045
# 0    95359050
# 0    95355045
# 0    95359050
# 0    95355045
# 0    95359050
# 0    95355045
# 0    95359050
# 0    95355045
# 0    95359050
# 0    95355045
# 0    95359050
# 0    95359050
# dtype: int64

# %%
df.memory_usage(deep=True).compute()
# Out:
# /home/cdsw/.local/lib/python3.10/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 25.31 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# Index     4000000
# col1      2500000
# col2      2000000
# col3      2000000
# col4      2000000
#            ...
# col995    2000000
# col996    2000000
# col997    2000000
# col998    2000000
# col999    2000000
# Length: 1000, dtype: int64

# %%
df.memory_usage_per_partition(index=True, deep=False).compute().count()
# Out:
# /home/cdsw/.local/lib/python3.10/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 25.32 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# 21

# %%
df.npartitions
# Out:
# 21
