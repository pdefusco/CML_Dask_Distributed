# %%
import os
import cdsw
from src.cml_extensions.dask_cluster.dask_cluster import DaskCluster

#os.environ[""]

cluster = DaskCluster(num_workers=10, worker_cpu=16, worker_memory=36, scheduler_cpu=16, scheduler_memory=36)
cluster.init()
# Out:
# --------------------
# Dask cluster started
# --------------------
#
# The Dask dashboard is running at
# https://6xlui5z35hhdc9fz.ml-6804005e-1f7.paul-aug.a465-9q4k.cloudera.site/status
#
# To connect to this Dask cluster from this CML Session,
# use the following Python code:
#   from dask.distributed import Client
#   client = Client('tcp://100.100.207.12:8786')

# %%
from multiprocessing import cpu_count

# %%
cpu_count()
# Out:
# 96

# %%
from dask.distributed import Client
client = Client('tcp://100.100.207.12:8786')

client
# Out:
# <Client: 'tcp://100.100.207.12:8786' processes=10 threads=960, memory=334.65 GiB>

# %% [markdown]
# ## Read HDF5

# %%
from pathlib import Path
import h5py
import os
HOME=os.getcwd()

# %%
from Sample_Data_Files.HDF5.HDF5reader_Odassea import getData

# %%
data_HDF5, metadata = getData(HOME+"/Sample_Data_Files/HDF5")
# Out:
# Found 1 HDF5 files
#
#
# Extracting data ...
#
# /home/cdsw/Sample_Data_Files/HDF5/DOSS_20240722T205526_000000Z.h5
# Done

# %%
import dask.dataframe as dd

df = dd.read_hdf('/home/cdsw/Sample_Data_Files/HDF5/DOSS_20240722T205526_000000Z.h5', '/*')  
df.info()
# Out:
# <class 'dask_expr.DataFrame'>
# Columns: 3 entries, StartChannel to Stride
# dtypes: int32(3)
# /home/cdsw/.local/lib/python3.11/site-packages/tables/attributeset.py:295: DataTypeWarning: Unsupported type for attribute 'TriggeredMeasurement' in node 'Acquisition'. Offending HDF5 class: 8
#   value = self._g_getattr(self._v_node, name)
# /home/cdsw/.local/lib/python3.11/site-packages/tables/attributeset.py:295: DataTypeWarning: Unsupported type for attribute 'UseRelativeStrain' in node 'Custom'. Offending HDF5 class: 8
#   value = self._g_getattr(self._v_node, name)
# /home/cdsw/.local/lib/python3.11/site-packages/tables/attributeset.py:295: DataTypeWarning: Unsupported type for attribute 'TransposedData' in node 'Custom'. Offending HDF5 class: 8
#   value = self._g_getattr(self._v_node, name)
# ...

# %%
df.head()
# Out:
#    StartChannel  EndChannel  Stride
# 0          3500        8500       1
